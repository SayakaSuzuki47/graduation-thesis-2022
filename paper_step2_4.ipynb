# %%
#マウント
from google.colab import drive
drive.mount('/content/drive')
# %cd "drive/MyDrive"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
##作業するディレクトリを指定する.
# %cd '/content/drive/MyDrive/Colab_Notebooks/paper'
# Out:
# /content/drive/MyDrive/Colab_Notebooks/paper

# %%
#関係するツールの導入
from bs4 import BeautifulSoup
import urllib
import urllib.request as req
import time
import requests
import os
import numpy as np
import pandas as pd
import collections
import re
from string import digits

# %%
#path_1: 入力となるpdfファイルの保存場所
path_1 = '/content/drive/MyDrive/Colab_Notebooks/paper/txt_test_2'

#path_2: 出力となるpdfファイルの保存場所
path_2 = '/content/drive/MyDrive/Colab_Notebooks/paper/paper_step2_test_2'

#files_list: path_1にあるファイル名の一覧を獲得する.
files_list = []
for filename in os.listdir(path_1):
  if os.path.isfile(os.path.join(path_1, filename)): #ファイルのみ取得
    files_list.append(filename)

# %%
#file_path = path_1 + "/" + files_list[0]
#with open(file_path,"r") as f:
#  for line in f:
#    r = line.replace('\n','')
#    print(r)
#f.close()

# %%
#take_out_word (str, str)-> str_lst
#(入力の場所,ファイルの名前)->txtファイルを読み込んで単語に分ける.小文字にして,ピリオドなどは除く. 
#doxygen文法
#
#指定テキストファイル内の英文を単語ごとの配列に整形します。
#主に半角スペース、コンマ、ピリオド、ハイフンで単語を分割します。
#また、数字の除去と大文字の小文字化も行っています。
#出力は文字列のリスト型で、順番は登場順になります。
#
#例
#"I'm a apple-pen."->["i","m","a","apple","pen"]
#
#param string path 読み込みファイルが存在するフォルダパス
#param string file_name 読み込むファイルの名前(拡張子込み)
#
#return string[] 分割された単語のリスト
#
#split_txt_to_words_list(read_folder_path,read_file_name)
def take_out_word (path,file_name):
  # split()でスペースと改行で分割したリストから単語を取り出す
  def word_list_of(string_file):
    #小文字にしてから英単語
    table = str.maketrans('', '', digits)
    string_file = string_file.translate(table)
    string_file =string_file.lower()
    string_beta = re.findall("\w+",string_file)
    return(string_beta)
  file_path = path + "/" + file_name
  with open(file_path) as f:
    r = f.read()
    s = word_list_of(r)
  return s

# %%
#take_out_word(path_1,files_list[0])

# %%
#get_lst_of_word (str,str,str)->
#(入力の場所,出力の場所,ファイルの名前)->take_out_wordを実行して出力の場所にtxtファイルで保存する.
#
#~~~
#内部でtext_out_word()を用いています
#
#
def get_lst_of_word (path_a,path_b,file_name):
  ##pdfpath_1 = path_1 + "/" + file_name
  pdfpath_b = path_b + "/" + file_name
  f= open( pdfpath_b ,"w")
  lst = take_out_word(path_a,file_name)
  for x in lst:
    f.write(str(x) + "\n")
  f.close()

# %%
#get_lst_of_wordをlstに対して繰り返し実行する.
txt_data =list(map( lambda x : get_lst_of_word(path_1, path_2, x), files_list))
