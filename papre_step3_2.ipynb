# %%
#マウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
##作業するディレクトリを指定する.
# %cd '/content/drive/MyDrive/Colab_Notebooks/paper'
# Out:
# /content/drive/MyDrive/Colab_Notebooks/paper

# %%
test = True

# %%
#関係するツールの導入
from bs4 import BeautifulSoup
import urllib
import urllib.request as req
import time
import requests
import os
import numpy as np
import pandas as pd
import collections
import re

# %%
#input_folder_path: 入力となるファイルの保存場所
input_folder_path = '/content/drive/MyDrive/Colab_Notebooks/paper/paper_step2_test2'
#output_folder_path: 出力となるpdfファイルの保存場所
output_folder_path = '/content/drive/MyDrive/Colab_Notebooks/paper/paper_step3_test2'

# %%
#read_file_names_list (str)-> str_lst
#("入力の場所(フォルダまでのパス)")->"入力の場所"にあるファイル名を入れたstring型のlistを返す
#
#"入力の場所"はあるフォルダへのパス.
#フォルダの中にあるファイルの名前を読み込む.
#ファイルの名前をリストに入れていく.
#ファイルの名前を入れたリストを出力として返す.
#
#例
#"/file"->["folder_1.txt","folder_2.txt","folder_3.txt"]
#
# read_file_names_list(input_path)
#
#param string input_path 読み込みファイルが存在するフォルダパス
#
#return string[] 分割されたファイル名のリスト
#

def read_file_names_list(input_path):
  files_list = []
  for filename in os.listdir(input_path):
    if os.path.isfile(os.path.join(input_path, filename)): #ファイルのみ取得
      files_list.append(filename)
  return(files_list)

# %%
file_names_list = read_file_names_list(input_folder_path)
file_names_list.sort(reverse=True)

# %%
file_names_list.sort(reverse=True)

# %%
if test:
  print(file_names_list[0:10])
# Out:
# ['C_5_Erman_Cineli.txt', 'C_4_Erman_Cineli.txt', 'C_3_Erman_Cineli.txt', 'C_2_Erman_Cineli.txt', 'C_1_Erman_Cineli.txt', 'B_5_Joan_Gimeno.txt', 'B_4_Joan_Gimeno.txt', 'B_3_Joan_Gimeno.txt', 'B_2_Joan_Gimeno.txt', 'B_1_Joan_Gimeno.txt']

# %%
#read_lst (str,str)->dct
#(入力の場所,ファイルの名前)->単語を数えてdct型にする(key,value)->(str,int)
def read_lst (path,file_name):
  file_path = path + "/" + file_name
  f = open(file_path,"r")
  list_row = []
  for x in f:
    list_row.append(x.rstrip("\n"))
    #以下のようにしてしまうと、改行コードがlistに入ってしまうため注意
    #list_row.append(x)
  f.close()
  word_lst = collections.Counter(list_row)
  return(word_lst)

# %%
d = read_lst(input_folder_path,file_names_list[0])

# %%
type(d)
# Out:
# collections.Counter

# %%
d['able']
# Out:
# 2

# %%
df = pd.DataFrame({})
df.append(d,ignore_index=True)
#forループ
# Out:
#    able  about  abouzaid  above  absolute  ...  ﬁrst  ﬁxed  ﬁxing   ﬂow  ﬂows
# 0   2.0    4.0       1.0   13.0       1.0  ...   6.0  39.0    2.0  13.0   2.0
#
# [1 rows x 1201 columns]

# %%
df = pd.DataFrame({})
for i in range(len(file_names_list)):
  d = read_lst(input_folder_path,file_names_list[i])
  df = df.append(d,ignore_index=True)
df = df.fillna(0)
df = df.astype(int)

# %%
df.head()
# Out:
#    able  about  abouzaid  above  ...  ﬂasks  ﬂocculating  ﬂocculent  ﬂuxes
# 0     2      4         1     13  ...      0            0          0      0
# 1     0      6         0      4  ...      0            0          0      0
# 2     2      2         0      6  ...      0            0          0      0
# 3     2      5         0      8  ...      0            0          0      0
# 4     2      3         0     10  ...      0            0          0      0
#
# [5 rows x 33700 columns]

# %%
df.to_csv(output_folder_path + '/' +"dict_dataframe.csv", sep=",")

# %%
#f = open(path_1 + "/" + files_list[0],"r")
#for line in f:
#  print(line.rstrip("\n"))
#f.close()
##read_lst(path_1,files_list[0])
#files_word_lst = list(map( lambda x : read_lst(path_1, x), files_list))

# %%
#get_txt_from_pdf (str,str,str)->
#(入力の場所,出力の場所,ファイルの名前)->txtファイルを出力の場所に作る. 
#def get_dct_of_word (path_a,path_b,file_name):
  ##pdfpath_1 = path_1 + "/" + file_name
#  pdfpath_b = path_b + "/" + file_name
#  dct_lst = read_lst (path_a,file_name)
#  f= open( pdfpath_b ,"w")
  #lst = take_out_word(path_a,file_name)
#  for key,value in dct_lst.items():
#    f.write('{0}, {1}\n'.format(key, value))
    #f.write(f'{key} \,{value}\n')
#  f.close()

# %%
#get_dct_of_word (path_1, path_2,files_list[0])

# %%
#get_dct_of_wordをlistに対して繰り返し実行
#txt_data =list(map( lambda x : get_dct_of_word (input_folder_path,output_folder_path,x), file_names_list))

# %%
 path_a = output_folder_path + "/" + 'file_names_list.txt'
f= open( path_a ,"w")
  #lst = take_out_word(path_a,file_name)
for x in file_names_list:
  f.write(str(x) + "\n")
    #f.write(f'{key} \,{value}\n')
f.close()
