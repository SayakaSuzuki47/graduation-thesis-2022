# %%
#マウント
from google.colab import drive
drive.mount('/content/drive')
##作業するディレクトリを指定する.
# %cd '/content/drive/MyDrive/Colab_Notebooks/arXiv_data'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab_Notebooks/arXiv_data

# %%
#input_folder_path: 入力となるファイルの保存場所
input_folder_path ='/content/drive/MyDrive/Colab_Notebooks/arXiv_data/Step_5'
#output_folder_path: 出力となるpdfファイルの保存場所
output_folder_path = '/content/drive/MyDrive/Colab_Notebooks/arXiv_data/Step_6'

# %%
#関係するツールの導入
import os
import numpy as np
import pandas as pd
import collections
import re
from string import digits

import sys
import time

# %%
 input_file_path = input_folder_path + "/df_dict_data_10000.csv"
 df = pd.read_csv(input_file_path)
 df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#          全単語数  limλց  kleinskaliger  divina  ...  eiθψxe  cbδb  ghom  uωv
# 0  44122778.0    5.0            1.0     3.0  ...     1.0   3.0   2.0  2.0
#
# [1 rows x 387508 columns]

# %%
df_dic = df.loc[ 0, :].sort_values( ascending = False)

# %%
type(df_dic)
# Out:
# pandas.core.series.Series

# %%
df_dic_index = list(df_dic.index)

# %%
df_dic_index.index('case')
# Out:
# 25

# %%
print(df_dic[ 470 : 500 ] )
# Out:
# before         13146.0
# amplitude      13120.0
# end            13067.0
# photon         13062.0
# geometry       13052.0
# cannot         13031.0
# mod            13023.0
# peak           12989.0
# complete       12978.0
# holds          12950.0
# continuous     12927.0
# nature         12878.0
# compared       12819.0
# clusters       12802.0
# per            12759.0
# write          12681.0
# leads          12680.0
# axis           12669.0
# rather         12619.0
# tions          12600.0
# diﬀerential    12593.0
# direct         12591.0
# maps           12583.0
# finally        12576.0
# account        12562.0
# relations      12524.0
# good           12478.0
# bounded        12460.0
# arbitrary      12431.0
# ﬂow            12423.0
# Name: 0, dtype: float64

# %%
df.loc[ 0, df.iloc[0,:] >100].sort_values( ascending = False)
# Out:
# 全単語数            44122778.0
# the              4497856.0
# and              1477065.0
# cid               904908.0
# for               741672.0
#                    ...
# turnaround           101.0
# qrpa                 101.0
# overwhelming         101.0
# soul                 101.0
# wade                 101.0
# Name: 0, Length: 17922, dtype: float64

# %%
df_index_list = list(df.loc[ 0, df.iloc[0,:] >100].sort_values( ascending = False).index)

# %%
len(df_index_list)
# Out:
# 17922

# %%
path_a = output_folder_path + "/" + 'df_index_list.txt'
f= open( path_a ,"w")
#lst = take_out_word(path_a,file_name)
for x in df_index_list:
    f.write(str(x) + "\n")
  #f.write(f'{key} \,{value}\n')
f.close()

# %%
44122778/387508
# Out:
# 113.86288283080607

# %%
f = open('/content/drive/MyDrive/Colab_Notebooks/arXiv_data/Step_0' +'/' + 'category_list_id_10000.txt',"r")
categories_list= []
for x in f:
  categories_list.append(x.rstrip("\n"))
    #以下のようにしてしまうと、改行コードがlistに入ってしまうため注意
    #list_row.append(x)
f.close()

# %%
f = open(input_folder_path + '/file_names_list_10000.txt',"r")
file_names_list = []
for x in f:
  file_names_list.append(x.rstrip("\n"))
    #以下のようにしてしまうと、改行コードがlistに入ってしまうため注意
    #list_row.append(x)
f.close()

# %%
len(categories_list)
# Out:
# 10000

# %% [markdown]
# #可換環 commutative ring Rings and Algebras

# %%
l_in = [s for s in enumerate(categories_list) if 'math.RA' in s]

# %%
print(l_in)
# Out:
# [(25, 'math.RA'), (73, 'math.RA'), (111, 'math.RA'), (1555, 'math.RA'), (1556, 'math.RA'), (1891, 'math.RA'), (2160, 'math.RA'), (2377, 'math.RA'), (2380, 'math.RA'), (2383, 'math.RA'), (2722, 'math.RA'), (3126, 'math.RA'), (3442, 'math.RA'), (3751, 'math.RA'), (4120, 'math.RA'), (5318, 'math.RA'), (6069, 'math.RA'), (6334, 'math.RA'), (6524, 'math.RA'), (7089, 'math.RA'), (7277, 'math.RA'), (7862, 'math.RA'), (8797, 'math.RA'), (8881, 'math.RA'), (9348, 'math.RA'), (9731, 'math.RA'), (9783, 'math.RA')]

# %%
RA_number = [25,73,111,1555,1556,1891,2160,2377, 2380, 2383, 2722, 3126, 3442, 3751, 4120, 5318, 6069, 6334, 6524 ,7089 ]
len(RA_number)
# Out:
# 20

# %%
for i in RA_number:
  print(file_names_list[i])
# Out:
# 0704.0026
# 0704.0074
# 0704.0112
# 0704.1556
# 0704.1557
# 0704.1892
# 0704.2161
# 0704.2378
# 0704.2381
# 0704.2384
# 0704.2723
# 0704.3127
# 0704.3443
# 0704.3752
# 0705.0118
# 0705.1316
# 0705.2067
# 0705.2332
# 0705.2522
# 0705.3087

# %% [markdown]
# #微分幾何 differential geometry
#
# ---

# %%
l_in = [s for s in enumerate(categories_list) if 'math.DG' in s]
print(l_in)
# Out:
# [(86, 'math.DG'), (209, 'math.DG'), (235, 'math.DG'), (316, 'math.DG'), (595, 'math.DG'), (852, 'math.DG'), (980, 'math.DG'), (1004, 'math.DG'), (1020, 'math.DG'), (1340, 'math.DG'), (1445, 'math.DG'), (1542, 'math.DG'), (1672, 'math.DG'), (1806, 'math.DG'), (1850, 'math.DG'), (1981, 'math.DG'), (1985, 'math.DG'), (2080, 'math.DG'), (2118, 'math.DG'), (2151, 'math.DG'), (2645, 'math.DG'), (2754, 'math.DG'), (2809, 'math.DG'), (2926, 'math.DG'), (2988, 'math.DG'), (3017, 'math.DG'), (3193, 'math.DG'), (3247, 'math.DG'), (3250, 'math.DG'), (3372, 'math.DG'), (3378, 'math.DG'), (3381, 'math.DG'), (3382, 'math.DG'), (3510, 'math.DG'), (3512, 'math.DG'), (3529, 'math.DG'), (3724, 'math.DG'), (3766, 'math.DG'), (3893, 'math.DG'), (4238, 'math.DG'), (4587, 'math.DG'), (4591, 'math.DG'), (4679, 'math.DG'), (4766, 'math.DG'), (4987, 'math.DG'), (5108, 'math.DG'), (5438, 'math.DG'), (5776, 'math.DG'), (6093, 'math.DG'), (6414, 'math.DG'), (6497, 'math.DG'), (6627, 'math.DG'), (6717, 'math.DG'), (6759, 'math.DG'), (7014, 'math.DG'), (7392, 'math.DG'), (7669, 'math.DG'), (7736, 'math.DG'), (7746, 'math.DG'), (7776, 'math.DG'), (7936, 'math.DG'), (7963, 'math.DG'), (7965, 'math.DG'), (8113, 'math.DG'), (8192, 'math.DG'), (8328, 'math.DG'), (8329, 'math.DG'), (8446, 'math.DG'), (8532, 'math.DG'), (8802, 'math.DG'), (8836, 'math.DG'), (8853, 'math.DG'), (8858, 'math.DG'), (8941, 'math.DG'), (9018, 'math.DG'), (9072, 'math.DG'), (9393, 'math.DG'), (9564, 'math.DG'), (9569, 'math.DG'), (9574, 'math.DG'), (9632, 'math.DG'), (9659, 'math.DG'), (9806, 'math.DG')]

# %%
DG_number = [86, 209, 235, 316, 595, 852, 980, 1004, 1020,1340, 1445,1542, 1672, 1806, 1850, 1981, 1985, 2080, 2118, 2151 ]
len(DG_number)
# Out:
# 20

# %%
for i in DG_number:
  print(file_names_list[i])
# Out:
# 0704.0087
# 0704.0210
# 0704.0236
# 0704.0317
# 0704.0596
# 0704.0853
# 0704.0981
# 0704.1005
# 0704.1021
# 0704.1341
# 0704.1446
# 0704.1543
# 0704.1673
# 0704.1807
# 0704.1851
# 0704.1982
# 0704.1986
# 0704.2081
# 0704.2119
# 0704.2152

# %% [markdown]
# #偏微分方程式 partial differential equation Analysis of PDEs

# %%
l_in = [s for s in enumerate(categories_list) if 'math.AP' in s]
print(l_in)
# Out:
# [(124, 'math.AP'), (323, 'math.AP'), (336, 'math.AP'), (401, 'math.AP'), (496, 'math.AP'), (564, 'math.AP'), (758, 'math.AP'), (1162, 'math.AP'), (1163, 'math.AP'), (1206, 'math.AP'), (1207, 'math.AP'), (1348, 'math.AP'), (1351, 'math.AP'), (1371, 'math.AP'), (1860, 'math.AP'), (1861, 'math.AP'), (1953, 'math.AP'), (2030, 'math.AP'), (2103, 'math.AP'), (2358, 'math.AP'), (2359, 'math.AP'), (2360, 'math.AP'), (2362, 'math.AP'), (2371, 'math.AP'), (2490, 'math.AP'), (2673, 'math.AP'), (2774, 'math.AP'), (2995, 'math.AP'), (3555, 'math.AP'), (3790, 'math.AP'), (4042, 'math.AP'), (4202, 'math.AP'), (4548, 'math.AP'), (4721, 'math.AP'), (4952, 'math.AP'), (5335, 'math.AP'), (5494, 'math.AP'), (5689, 'math.AP'), (5716, 'math.AP'), (5830, 'math.AP'), (5857, 'math.AP'), (6109, 'math.AP'), (6287, 'math.AP'), (6289, 'math.AP'), (6448, 'math.AP'), (6812, 'math.AP'), (6826, 'math.AP'), (6827, 'math.AP'), (6851, 'math.AP'), (6880, 'math.AP'), (7303, 'math.AP'), (7359, 'math.AP'), (7364, 'math.AP'), (7661, 'math.AP'), (7676, 'math.AP'), (7810, 'math.AP'), (7961, 'math.AP'), (8006, 'math.AP'), (8007, 'math.AP'), (8241, 'math.AP'), (8246, 'math.AP'), (8533, 'math.AP'), (9015, 'math.AP'), (9060, 'math.AP'), (9230, 'math.AP'), (9301, 'math.AP'), (9505, 'math.AP'), (9559, 'math.AP'), (9562, 'math.AP'), (9734, 'math.AP'), (9763, 'math.AP'), (9860, 'math.AP'), (9864, 'math.AP'), (9912, 'math.AP')]

# %%
AP_number = [ 124, 323, 336, 401, 496, 564, 785, 1162, 1163,1206, 1207, 1348, 1351, 1371, 1860, 1861, 1953,2030, 2103, 2358 ]
len(AP_number)
# Out:
# 20

# %%
for i in AP_number:
  print(file_names_list[i])
# Out:
# 0704.0125
# 0704.0324
# 0704.0337
# 0704.0402
# 0704.0497
# 0704.0565
# 0704.0786
# 0704.1163
# 0704.1164
# 0704.1207
# 0704.1208
# 0704.1349
# 0704.1352
# 0704.1372
# 0704.1861
# 0704.1862
# 0704.1954
# 0704.2031
# 0704.2104
# 0704.2359

# %% [markdown]
# #k-meansに使うリスト

# %%
k_means_list = RA_number[0:10]
k_means_list[len(k_means_list):len(k_means_list)] = DG_number[0:10]
k_means_list[len(k_means_list):len(k_means_list)] = AP_number[0:10]
len(k_means_list)
# Out:
# 30

# %%
k_means_id_list = []
for i in k_means_list :
  id_number = file_names_list[i]
  k_means_id_list.append( id_number )

# %%
path_a = output_folder_path + "/" + 'k_means_id_list_paper.txt'
f= open( path_a ,"w")
#lst = take_out_word(path_a,file_name)
for x in k_means_id_list:
    f.write(str(x) + "\n")
  #f.write(f'{key} \,{value}\n')
f.close()

# %%
k_means_list = RA_number[0:20]
k_means_list[len(k_means_list):len(k_means_list)] = DG_number
k_means_list[len(k_means_list):len(k_means_list)] = AP_number
len(k_means_list)
# Out:
# 60

# %%
k_means_id_list = []
for i in k_means_list :
  id_number = file_names_list[i]
  k_means_id_list.append( id_number )

# %%
path_a = output_folder_path + "/" + 'k_means_id_list_paper_20.txt'
f= open( path_a ,"w")
#lst = take_out_word(path_a,file_name)
for x in k_means_id_list:
    f.write(str(x) + "\n")
  #f.write(f'{key} \,{value}\n')
f.close()

# %%
k_means_id_list

# %%
path_a = output_folder_path + "/" + 'k_means_id_list_paper.txt'
f= open( path_a ,"w")
#lst = take_out_word(path_a,file_name)
for x in k_means_id_list:
    f.write(str(x) + "\n")
  #f.write(f'{key} \,{value}\n')
f.close()

# %%
for i in k_means_id_list:
   input_file_path = '/content/drive/MyDrive/Colab_Notebooks/arXiv_data/Step_4' + '/' + i + '.csv'
   d = pd.read_csv(input_file_path)
   d = d.drop('Unnamed: 0', axis=1)
   d.insert(0, '全単語数',d.sum(axis=1))
   df = df.append(d,ignore_index=True)
df = df.fillna(0)
df = df.astype(int)

# %%
df.head()

# %%
df.loc['k-means対象'] = df.loc[1:len(df)].sum(axis=0)

# %%
display(df)

# %%
df.loc['全体の頻度'] = df.loc[0]/df.loc[0,'全単語数']

# %%
display(df)

# %%
df = df.loc[:,df_index_list]

# %%
df

# %%
df_z_value = pd.DataFrame({})
#全体の頻度
word_freqs = df.loc['全体の頻度']
for i in range( len(k_means_id_list) + 1):
  #単語の個数
  word_number_i = df.loc[i]
  #word_number_i =word_number_i.drop('全単語数')<-これをすると単語がランダム,不明になってしまう
  #ファイルの単語数
  numbers_file_word = df.loc[i,'全単語数']
  #z値
  z = (word_number_i - numbers_file_word * word_freqs)/np.sqrt(numbers_file_word*word_freqs*(1-word_freqs))
  z.name = i
  z = pd.DataFrame([z])
  df_z_value = pd.concat([df_z_value, z], axis=0)

# %%
#単語の個数
word_number_i = df.loc['k-means対象'] 
#word_number_i =word_number_i.drop('全単語数')<-これをすると単語がランダム,不明になってしまう
#ファイルの単語数
numbers_file_word = df.loc[i,'全単語数']
#z値
z = (word_number_i - numbers_file_word * word_freqs)/np.sqrt(numbers_file_word*word_freqs*(1-word_freqs))
z.name = 'k-means対象'
z = pd.DataFrame([z])
df_z_value = pd.concat([df_z_value, z], axis=0)

# %%
display(df_z_value)

# %%
df_z_value = df_z_value.drop('全単語数',axis = 1)
display(df_z_value)

# %% [markdown]
# #各ファイル上位n単語を取り出す．

# %%
def make_df_top_n_index(df,n,file_names_list):
  top_n_index = df.loc[1].sort_values(ascending = False)[1:n+1].index
  for i in range(2,len(file_names_list)+1):
    top_n_index = top_n_index.append(df.loc[i].sort_values(ascending = False)[1:n+1].index)
  df_z_top_n = df.loc[:,top_n_index]
  df_z_top_n = df_z_top_n.loc[:,~df_z_top_n.columns.duplicated()]
  return( df_z_top_n )

# %%
df_z_top_n_100 = make_df_top_n_index(df_z_value,10,k_means_id_list)

# %%
display(df_z_top_n_100)

# %%
df_z_top_n_100[1:31].to_csv(output_folder_path + '/' +"rate_data_100_paper.csv", sep=",")

# %% [markdown]
# #対象のファイル全体でのz値上位n単語

# %%
n = 100
top_n_index = df_z_value .loc['k-means対象'].sort_values(ascending = False)[1:n+1].index
df_z_top_n = df_z_value .loc[:,top_n_index]
df_z_top_n = df_z_top_n.iloc[1:len(k_means_id_list)+1,~df_z_top_n.columns.duplicated()]

# %%
display(df_z_top_n)

# %%
df_z_top_n.to_csv(output_folder_path + '/' +"rate_data_k_meansfiles__100_paper_20.csv", sep=",")
