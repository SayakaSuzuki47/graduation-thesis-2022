# %%
#マウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
##作業するディレクトリを指定する.
# %cd '/content/drive/MyDrive/Colab_Notebooks/paper'
# Out:
# /content/drive/MyDrive/Colab_Notebooks/paper

# %%
#関係するツールの導入
from bs4 import BeautifulSoup
import urllib
import urllib.request as req
import time
import requests
import os
import numpy as np
import re

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading PyPDF2-1.26.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 4.2 MB/s
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61101 sha256=5833a36ad027545c28bad00d478aa2a98eab34eee34fb72c2f472545f4a2da37
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
# !pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer.six-20211012-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 5.9 MB/s
# Requirement already satisfied: chardet in /usr/local/lib/python3.7/dist-packages (from pdfminer.six) (3.0.4)
# Collecting cryptography
#   Downloading cryptography-35.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 23.9 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->pdfminer.six) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->pdfminer.six) (2.20)
# Installing collected packages: cryptography, pdfminer.six
# Successfully installed cryptography-35.0.0 pdfminer.six-20211012

# %%
#pdf2txt.pyのダウンロード
py_url ='https://github.com/pdfminer/pdfminer.six/blob/master/tools/pdf2txt.py'
py_fn='pdf2txt.py'
os.system("wget -O " + str(py_fn) + " " + str(py_url))
# Out:
# 0

# %%
#path_1: 入力となるファイルの保存場所
path_1 = '/content/drive/MyDrive/Colab_Notebooks/paper/pdf_file_test_2'
#input,import,read _folder_path

#path_2: 出力となるpdfファイルの保存場所
path_2 = '/content/drive/MyDrive/Colab_Notebooks/paper/txt_test_2'
#output,export,write _folder_path

#files_list: path_1にあるファイル名の一覧を獲得する.
#read_file_names_list
files_list = []
for filename in os.listdir(path_1):
  if os.path.isfile(os.path.join(path_1, filename)): #ファイルのみ取得
    files_list.append(filename)

# %%
len(files_list)
# Out:
# 150

# %%
#get_txt_from_pdf (str,str,str)->
#(入力の場所,出力の場所,ファイルの名前)->txtファイルを出力の場所に作る. 
def get_txt_from_pdf (import_folder_path,export_folder_path,file_name):
  pdfpath_1 = import_folder_path + "/" + file_name
  pdfpath_2 = export_folder_path + "/" 
  #pdf2txt.pyを用いてpdfファイルをテキスト変換
  lines = !pdf2txt.py { pdfpath_1 }
  txt = '\n'.join(lines)
  target = '.pdf'#ext_target
  idx = file_name.find(target)
  r = file_name[:idx] 
  rename = pdfpath_2 + r + ".txt"
  f= open( rename ,"w")
  f.write(txt)
  f.close()

# %%
#files_list

# %%
#get_txt_from_pdfをlistに対して繰り返し実行
list(map( lambda x:get_txt_from_pdf(path_1,path_2,x),files_list))
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
