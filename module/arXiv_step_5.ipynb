# %%
#マウント
from google.colab import drive
drive.mount('/content/drive')
##作業するディレクトリを指定する.
# %cd '/content/drive/MyDrive/Colab_Notebooks/arXiv_data'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab_Notebooks/arXiv_data

# %%
#input_folder_path: 入力となるファイルの保存場所
input_folder_path ='/content/drive/MyDrive/Colab_Notebooks/arXiv_data/Step_5'
#output_folder_path: 出力となるpdfファイルの保存場所
output_folder_path = '/content/drive/MyDrive/Colab_Notebooks/arXiv_data/Step_6'

# %%
#関係するツールの導入
import os
import numpy as np
import pandas as pd
import collections
import re
from string import digits

import sys
import time

# %%
 input_file_path = input_folder_path + "/df_dict_data_10000.csv"
 df = pd.read_csv(input_file_path)
 df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#          全単語数  limλց  kleinskaliger  divina  ...  eiθψxe  cbδb  ghom  uωv
# 0  44122778.0    5.0            1.0     3.0  ...     1.0   3.0   2.0  2.0
#
# [1 rows x 387508 columns]

# %%
f = open('/content/drive/MyDrive/Colab_Notebooks/arXiv_data/Step_0' +'/' + 'category_list_id_10000.txt',"r")
categories_list= []
for x in f:
  categories_list.append(x.rstrip("\n"))
    #以下のようにしてしまうと、改行コードがlistに入ってしまうため注意
    #list_row.append(x)
f.close()

# %%
f = open(input_folder_path + '/file_names_list_10000.txt',"r")
file_names_list = []
for x in f:
  file_names_list.append(x.rstrip("\n"))
    #以下のようにしてしまうと、改行コードがlistに入ってしまうため注意
    #list_row.append(x)
f.close()

# %%
len(categories_list)
# Out:
# 10000

# %%
categories_list[241:260]
# Out:
# ['astro-ph',
#  'cond-mat.str-el',
#  'cond-mat.mtrl-sci',
#  'hep-th hep-ph',
#  'cond-mat.mes-hall',
#  'hep-th gr-qc',
#  'physics.optics math-ph math.MP',
#  'cond-mat.str-el',
#  'cond-mat.str-el cond-mat.dis-nn',
#  'quant-ph',
#  'hep-ph',
#  'astro-ph',
#  'hep-ph',
#  'astro-ph',
#  'astro-ph',
#  'math.SG math.AG',
#  'hep-th cond-mat.stat-mech',
#  'astro-ph',
#  'math.FA math.AP']

# %% [markdown]
# hep-ph High energy physis phenomenology 0,14,15,28,31

# %% [markdown]
# math.NT Number Theory 10,11,12

# %% [markdown]
# math.C0 Combinatorics 1,3,9,48,198

# %%
for i in [1,3,9,48,198]:
  print(categories_list[i])
# Out:
# math.CO cs.CG
# math.CO
# math.CO
# math.CO
# math.CO math.GR

# %%
'math.C0 cs.CG '
# Out:
# 'math.C0 cs.CG '

# %%
k_means_list = [0,14,15,28,31,10,11,12,1,3,9,48,198]

# %%
k_means_id_list = []
for i in [0,14,15,28,31,10,11,12,1,3,9,48,198]:
  id_number = file_names_list[i]
  k_means_id_list.append( id_number )

# %%
k_means_id_list
# Out:
# ['0704.0001',
#  '0704.0015',
#  '0704.0016',
#  '0704.0029',
#  '0704.0032',
#  '0704.0011',
#  '0704.0012',
#  '0704.0013',
#  '0704.0002',
#  '0704.0004',
#  '0704.0010',
#  '0704.0049',
#  '0704.0199']

# %%
path_a = output_folder_path + "/" + 'k_means_id_list.txt'
f= open( path_a ,"w")
#lst = take_out_word(path_a,file_name)
for x in k_means_id_list:
    f.write(str(x) + "\n")
  #f.write(f'{key} \,{value}\n')
f.close()

# %%
for i in k_means_id_list:
   input_file_path = '/content/drive/MyDrive/Colab_Notebooks/arXiv_data/Step_4' + '/' + i + '.csv'
   d = pd.read_csv(input_file_path)
   d = d.drop('Unnamed: 0', axis=1)
   d.insert(0, '全単語数',d.sum(axis=1))
   df = df.append(d,ignore_index=True)
df = df.fillna(0)
df = df.astype(int)

# %%
df.head()
# Out:
#        全単語数  limλց  kleinskaliger  divina  ...  eiθψxe  cbδb  ghom  uωv
# 0  44122778      5              1       3  ...       1     3     2    2
# 1     11159      0              0       0  ...       0     0     0    0
# 2      5437      0              0       0  ...       0     0     0    0
# 3      2663      0              0       0  ...       0     0     0    0
# 4      2879      0              0       0  ...       0     0     0    0
#
# [5 rows x 387508 columns]

# %%
df.loc['k-means対象'] = df.loc[1:len(df)].sum(axis=0)

# %%
display(df)
# Out:
#                全単語数  limλց  kleinskaliger  divina  ...  eiθψxe  cbδb  ghom  uωv
# 0          44122778      5              1       3  ...       1     3     2    2
# 1             11159      0              0       0  ...       0     0     0    0
# 2              5437      0              0       0  ...       0     0     0    0
# 3              2663      0              0       0  ...       0     0     0    0
# 4              2879      0              0       0  ...       0     0     0    0
# 5              8918      0              0       0  ...       0     0     0    0
# 6              2901      0              0       0  ...       0     0     0    0
# 7              1723      0              0       0  ...       0     0     0    0
# 8              2749      0              0       0  ...       0     0     0    0
# 9              5983      0              0       0  ...       0     0     0    0
# 10             1888      0              0       0  ...       0     0     0    0
# 11             6917      0              0       0  ...       0     0     0    0
# 12             3034      0              0       0  ...       0     0     0    0
# 13            13225      0              0       0  ...       0     0     0    0
# k-means対象     69476      0              0       0  ...       0     0     0    0
#
# [15 rows x 387508 columns]

# %%
df.loc['全体の頻度'] = df.loc[0]/df.loc[0,'全単語数']

# %%
display(df)
# Out:
#                  全単語数         limλց  ...          ghom           uωv
# 0          44122778.0  5.000000e+00  ...  2.000000e+00  2.000000e+00
# 1             11159.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 2              5437.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 3              2663.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 4              2879.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 5              8918.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 6              2901.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 7              1723.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 8              2749.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 9              5983.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 10             1888.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 11             6917.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 12             3034.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 13            13225.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# k-means対象     69476.0  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 全体の頻度             1.0  1.133202e-07  ...  4.532806e-08  4.532806e-08
#
# [16 rows x 387508 columns]

# %%
df_z_value = pd.DataFrame({})
#全体の頻度
word_freqs = df.loc['全体の頻度']
for i in range( len(k_means_id_list) + 1):
  #単語の個数
  word_number_i = df.loc[i]
  #word_number_i =word_number_i.drop('全単語数')<-これをすると単語がランダム,不明になってしまう
  #ファイルの単語数
  numbers_file_word = df.loc[i,'全単語数']
  #z値
  z = (word_number_i - numbers_file_word * word_freqs)/np.sqrt(numbers_file_word*word_freqs*(1-word_freqs))
  z.name = i
  z = pd.DataFrame([z])
  df_z_value = pd.concat([df_z_value, z], axis=0)

# %%
#単語の個数
word_number_i = df.loc['k-means対象'] 
#word_number_i =word_number_i.drop('全単語数')<-これをすると単語がランダム,不明になってしまう
#ファイルの単語数
numbers_file_word = df.loc[i,'全単語数']
#z値
z = (word_number_i - numbers_file_word * word_freqs)/np.sqrt(numbers_file_word*word_freqs*(1-word_freqs))
z.name = 'k-means対象'
z = pd.DataFrame([z])
df_z_value = pd.concat([df_z_value, z], axis=0)

# %%
display(df_z_value)
# Out:
#            全単語数     limλց  kleinskaliger  ...      cbδb      ghom       uωv
# 0           NaN  0.000000       0.000000  ...  0.000000  0.000000  0.000000
# 1           NaN -0.035560      -0.015903  ... -0.027545 -0.022490 -0.022490
# 2           NaN -0.024822      -0.011101  ... -0.019227 -0.015699 -0.015699
# 3           NaN -0.017372      -0.007769  ... -0.013456 -0.010987 -0.010987
# 4           NaN -0.018062      -0.008078  ... -0.013991 -0.011424 -0.011424
# 5           NaN -0.031790      -0.014217  ... -0.024624 -0.020106 -0.020106
# 6           NaN -0.018131      -0.008109  ... -0.014044 -0.011467 -0.011467
# 7           NaN -0.013973      -0.006249  ... -0.010824 -0.008837 -0.008837
# 8           NaN -0.017650      -0.007893  ... -0.013672 -0.011163 -0.011163
# 9           NaN -0.026038      -0.011645  ... -0.020169 -0.016468 -0.016468
# 10          NaN -0.014627      -0.006541  ... -0.011330 -0.009251 -0.009251
# 11          NaN -0.027997      -0.012521  ... -0.021686 -0.017707 -0.017707
# 12          NaN -0.018542      -0.008292  ... -0.014363 -0.011727 -0.011727
# 13          NaN -0.038713      -0.017313  ... -0.029987 -0.024484 -0.024484
# k-means対象   inf -0.038713      -0.017313  ... -0.029987 -0.024484 -0.024484
#
# [15 rows x 387508 columns]

# %%
df_z_value = df_z_value.drop('全単語数',axis = 1)
display(df_z_value)
# Out:
#               limλց  kleinskaliger    divina  ...      cbδb      ghom       uωv
# 0          0.000000       0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1         -0.035560      -0.015903 -0.027545  ... -0.027545 -0.022490 -0.022490
# 2         -0.024822      -0.011101 -0.019227  ... -0.019227 -0.015699 -0.015699
# 3         -0.017372      -0.007769 -0.013456  ... -0.013456 -0.010987 -0.010987
# 4         -0.018062      -0.008078 -0.013991  ... -0.013991 -0.011424 -0.011424
# 5         -0.031790      -0.014217 -0.024624  ... -0.024624 -0.020106 -0.020106
# 6         -0.018131      -0.008109 -0.014044  ... -0.014044 -0.011467 -0.011467
# 7         -0.013973      -0.006249 -0.010824  ... -0.010824 -0.008837 -0.008837
# 8         -0.017650      -0.007893 -0.013672  ... -0.013672 -0.011163 -0.011163
# 9         -0.026038      -0.011645 -0.020169  ... -0.020169 -0.016468 -0.016468
# 10        -0.014627      -0.006541 -0.011330  ... -0.011330 -0.009251 -0.009251
# 11        -0.027997      -0.012521 -0.021686  ... -0.021686 -0.017707 -0.017707
# 12        -0.018542      -0.008292 -0.014363  ... -0.014363 -0.011727 -0.011727
# 13        -0.038713      -0.017313 -0.029987  ... -0.029987 -0.024484 -0.024484
# k-means対象 -0.038713      -0.017313 -0.029987  ... -0.029987 -0.024484 -0.024484
#
# [15 rows x 387507 columns]

# %% [markdown]
# #各ファイル上位n単語を取り出す．

# %%
def make_df_top_n_index(df,n,file_names_list):
  top_n_index = df.loc[1].sort_values(ascending = False)[1:n+1].index
  for i in range(2,len(file_names_list)+1):
    top_n_index = top_n_index.append(df.loc[i].sort_values(ascending = False)[1:n+1].index)
  df_z_top_n = df.loc[:,top_n_index]
  df_z_top_n = df_z_top_n.loc[:,~df_z_top_n.columns.duplicated()]
  return( df_z_top_n )

# %%
df_z_top_n_100 = make_df_top_n_index(df_z_value,10,k_means_id_list)

# %%
display(df_z_top_n_100)

# %%
df_z_top_n_100[1:14].to_csv(output_folder_path + '/' +"rate_data_100.csv", sep=",")

# %% [markdown]
# #対象のファイル全体でのz値上位n単語

# %%
n = 100
top_n_index = df_z_value .loc['k-means対象'].sort_values(ascending = False)[1:n+1].index
df_z_top_n = df_z_value .loc[:,top_n_index]
df_z_top_n = df_z_top_n.iloc[1:len(k_means_id_list)+1,~df_z_top_n.columns.duplicated()]

# %%
display( df_z_top_n)

# %%
df_z_top_n.to_csv(output_folder_path + '/' +"rate_data_k_meansfiles__100.csv", sep=",")
