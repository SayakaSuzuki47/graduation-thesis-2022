# %%
#マウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
##作業するディレクトリを指定する.
# %cd '/content/drive/MyDrive/Colab_Notebooks/paper'
# Out:
# /content/drive/MyDrive/Colab_Notebooks/paper

# %%
#test
test = True

# %%
#関係するツールの導入
from bs4 import BeautifulSoup
import urllib
import urllib.request as req
import time
import requests
import os
import numpy as np
import pandas as pd
import collections
import re
import csv

# %%
#input_folder_path: 入力となるファイルの保存場所
input_folder_path = '/content/drive/MyDrive/Colab_Notebooks/paper/paper_step4_test2'
#output_folder_path: 出力となるpdfファイルの保存場所
output_folder_path = '/content/drive/MyDrive/Colab_Notebooks/paper/paper_step5_test2'

# %%
f = open(input_folder_path + '/file_names_list.txt',"r")
file_names_list= []
for x in f:
  file_names_list.append(x.rstrip("\n"))
    #以下のようにしてしまうと、改行コードがlistに入ってしまうため注意
    #list_row.append(x)
f.close()

# %%
if c = 0:
  for i in range(10) :
    i = i + 2

# %%
file_names_list = file_names_list[0:20]

# %%
if test:
  print(file_names_list[0])
# Out:
# C_5_Erman_Cineli.txt

# %%
#f = open(input_folder_path+ '/top_n_dictionary_20.txt',"r")#
#top_n_dictionary = []
#for x in f:
#  top_n_dictionary.append(x.rstrip("\n"))
    #以下のようにしてしまうと、改行コードがlistに入ってしまうため注意
    #list_row.append(x)
#f.close()

# %%
#if test:
#  print(len(top_n_dictionary))

# %%
path_a = input_folder_path + "/rate_data_sub_20.csv"
df = pd.read_csv(path_a)
df = df.drop('Unnamed: 0', axis=1)

# %%
df = df[0:20]

# %%
display(df)
# Out:
#          the  homology     floer  ...   strains  biotechnol  hydrolysates
# 0   0.037989  0.017531  0.016579  ... -0.000071   -0.000062     -0.000061
# 1   0.005092  0.001994  0.002636  ... -0.000071   -0.000062     -0.000061
# 2   0.021665  0.001643  0.006748  ... -0.000071   -0.000062     -0.000061
# 3   0.008946  0.001820  0.009380  ... -0.000071   -0.000062     -0.000061
# 4  -0.000038  0.003328  0.009620  ... -0.000071   -0.000062     -0.000061
# 5   0.012155 -0.000417 -0.000465  ... -0.000071   -0.000062     -0.000061
# 6   0.037475 -0.000417 -0.000465  ... -0.000071   -0.000062     -0.000061
# 7   0.034830 -0.000417 -0.000465  ... -0.000071   -0.000062     -0.000061
# 8   0.039715 -0.000417 -0.000465  ... -0.000071   -0.000062     -0.000061
# 9   0.024856 -0.000417 -0.000465  ... -0.000071   -0.000062     -0.000061
# 10 -0.003981  0.000221 -0.000465  ... -0.000071   -0.000062     -0.000061
# 11 -0.003787  0.000040 -0.000465  ... -0.000071   -0.000062     -0.000061
# 12 -0.003249  0.000124 -0.000465  ... -0.000071   -0.000062     -0.000061
# 13 -0.008965 -0.000153 -0.000465  ... -0.000071   -0.000062     -0.000061
# 14  0.021637  0.004093 -0.000465  ... -0.000071   -0.000062     -0.000061
# 15  0.005505 -0.000417 -0.000465  ... -0.000071   -0.000062     -0.000061
# 16 -0.050374 -0.000417 -0.000465  ... -0.000071   -0.000062     -0.000061
# 17 -0.003579 -0.000417 -0.000465  ... -0.000071   -0.000062     -0.000061
# 18  0.014548 -0.000417 -0.000465  ... -0.000071   -0.000062     -0.000061
# 19 -0.008727 -0.000417 -0.000465  ... -0.000071   -0.000062     -0.000061
#
# [20 rows x 1244 columns]

# %% [markdown]
# ##K-means法

# %%
from matplotlib import pyplot as plt
from sklearn import datasets, preprocessing
from sklearn.cluster import KMeans
import numpy as np

# %%
#クラスタリングの結果からfile名をクラスタごとに分ける
# show_result (str_list,int_array,int) -> str_list_list
def show_result (file, result_k,n):
  result_file = []
  for i in range(n):
    result_file.append([])
  for j in range(len(file)):
    l = result_k[j]
    result_file[l].append(file[j])
  #return print(result_file)
  return result_file

# %%
#傾向となる単語を取りだす
#df: データ k_means_result:k-means法でクラスタリングした結果, n:クラスタリングの個数
def trend (df,k_means_result,n,m,dictionary):
  trend = []
  df['cluster_id']=k_means_result
  for i in range(n):
    trend_n = df[df['cluster_id']==i].mean()
    trend_number = trend_n.drop('cluster_id', axis=0)
    trend_word = trend_number.sort_values(ascending = False)[0:m].index
    trend.append((i,trend_word))
  #return print(trend)
  return trend

# %%
#k-means
result = KMeans(n_clusters=5).fit_predict(df)

# %%
if False:
  df['cluster_id']=result
  i =1
  trend_n = df[df['cluster_id']==i].mean()
  trend_n[1963]
  #trend_number = trend_n.drop('cluster_id', axis=0)
  #trend_number = trend_number.drop('Unnamed: 0', axis=0)
  trend_number.index
  trend_number
  trend_n_sub = trend_number.sort_values( ascending=False)
  trend_n_sub
  trend_number_list = list(trend_n_sub.index[0:5])
  trend_number_list
  df.head()
  result

# %% [markdown]
# ##10単語ずつ取り出して辞書を作ったもの

# %%
show_result(file_names_list,result,5)
# Out:
# [['B_5_Joan_Gimeno.txt',
#   'A_5_Tobias_Barthel.txt',
#   'A_1_Tobias_Barthel.txt',
#   '2110.15949.txt',
#   '2110.15926.txt',
#   '2110.15914.txt',
#   '2110.15907.txt'],
#  ['A_4_Tobias_Barthel.txt',
#   'A_3_Tobias_Barthel.txt',
#   'A_2_Tobias_Barthel.txt'],
#  ['C_5_Erman_Cineli.txt',
#   'B_4_Joan_Gimeno.txt',
#   'B_3_Joan_Gimeno.txt',
#   'B_2_Joan_Gimeno.txt',
#   'B_1_Joan_Gimeno.txt'],
#  ['C_4_Erman_Cineli.txt',
#   'C_3_Erman_Cineli.txt',
#   'C_2_Erman_Cineli.txt',
#   'C_1_Erman_Cineli.txt'],
#  ['2110.15943.txt']]

# %%
if test:
  df.columns

# %%
#それぞれのクラスターでよく用いられる単語10個
trend(df,result,5,10,df.columns)
# Out:
# [(0, Index(['the', 'data', 'state', 'latent', 'sequence', 'learning', 'action',
#          'reward', 'spectral', 'attention'],
#         dtype='object')),
#  (1,
#   Index(['spc', 'support', 'category', 'balmer', 'supp', 'tensor', 'theorem',
#          'cid', 'supph', 'remark'],
#         dtype='object')),
#  (2, Index(['the', 'spin', 'orbit', 'periodic', 'problem', 'homology', 'floer',
#          'kam', 'cos', 'equation'],
#         dtype='object')),
#  (3,
#   Index(['the', 'and', 'floer', 'hamiltonian', 'pseudo', 'periodic', 'product',
#          'this', 'non', 'see'],
#         dtype='object')),
#  (4, Index(['tasks', 'training', 'meta', 'task', 'shot', 'metaicl', 'context',
#          'target', 'glue', 'tweet_eval'],
#         dtype='object'))]

# %% [markdown]
# ##100単語ずつ取り出して辞書を作ったもの

# %%
path_a = input_folder_path + "/rate_data_sub_100.csv"
df = pd.read_csv(path_a)
df = df.drop('Unnamed: 0', axis=1)
df = df[0:20]

# %%
#k-means
result = KMeans(n_clusters=4).fit_predict(df)

# %%
show_result(file_names_list,result,4)
# Out:
# [['C_5_Erman_Cineli.txt',
#   'B_5_Joan_Gimeno.txt',
#   'B_4_Joan_Gimeno.txt',
#   'B_3_Joan_Gimeno.txt',
#   'B_2_Joan_Gimeno.txt',
#   'B_1_Joan_Gimeno.txt',
#   'A_1_Tobias_Barthel.txt',
#   '2110.15914.txt'],
#  ['2110.15949.txt', '2110.15943.txt', '2110.15926.txt', '2110.15907.txt'],
#  ['C_4_Erman_Cineli.txt',
#   'C_3_Erman_Cineli.txt',
#   'C_2_Erman_Cineli.txt',
#   'C_1_Erman_Cineli.txt',
#   'A_5_Tobias_Barthel.txt'],
#  ['A_4_Tobias_Barthel.txt',
#   'A_3_Tobias_Barthel.txt',
#   'A_2_Tobias_Barthel.txt']]

# %%
#それぞれのクラスターでよく用いられる単語10個
trend(df,result,4,10,df.columns)
# Out:
# [(0,
#   Index(['the', 'spin', 'orbit', 'periodic', 'homology', 'equations', 'that',
#          'equation', 'data', 'problem'],
#         dtype='object')),
#  (1, Index(['learning', 'training', 'task', 'tasks', 'state', 'latent', 'meta',
#          'agent', 'control', 'reward'],
#         dtype='object')),
#  (2, Index(['the', 'floer', 'and', 'theorem', 'this', 'hamiltonian', 'pseudo',
#          'see', 'product', 'that'],
#         dtype='object')),
#  (3,
#   Index(['spc', 'support', 'category', 'balmer', 'supp', 'tensor', 'theorem',
#          'cid', 'supph', 'remark'],
#         dtype='object'))]

# %%
display(df)
# Out:
#          the  homology     floer  ...  compounds    uptake  cluster_id
# 0   0.037989  0.017531  0.016579  ...  -0.000024 -0.000018           0
# 1   0.005092  0.001994  0.002636  ...  -0.000024 -0.000018           2
# 2   0.021665  0.001643  0.006748  ...  -0.000024 -0.000018           2
# 3   0.008946  0.001820  0.009380  ...  -0.000024 -0.000018           2
# 4  -0.000038  0.003328  0.009620  ...  -0.000024 -0.000018           2
# 5   0.012155 -0.000417 -0.000465  ...  -0.000024 -0.000018           0
# 6   0.037475 -0.000417 -0.000465  ...  -0.000024 -0.000018           0
# 7   0.034830 -0.000417 -0.000465  ...  -0.000024 -0.000018           0
# 8   0.039715 -0.000417 -0.000465  ...  -0.000024 -0.000018           0
# 9   0.024856 -0.000417 -0.000465  ...  -0.000024 -0.000018           0
# 10 -0.003981  0.000221 -0.000465  ...  -0.000024 -0.000018           2
# 11 -0.003787  0.000040 -0.000465  ...  -0.000024 -0.000018           3
# 12 -0.003249  0.000124 -0.000465  ...  -0.000024 -0.000018           3
# 13 -0.008965 -0.000153 -0.000465  ...  -0.000024 -0.000018           3
# 14  0.021637  0.004093 -0.000465  ...  -0.000024 -0.000018           0
# 15  0.005505 -0.000417 -0.000465  ...  -0.000024 -0.000018           1
# 16 -0.050374 -0.000417 -0.000465  ...  -0.000024 -0.000018           1
# 17 -0.003579 -0.000417 -0.000465  ...  -0.000024 -0.000018           1
# 18  0.014548 -0.000417 -0.000465  ...  -0.000024 -0.000018           0
# 19 -0.008727 -0.000417 -0.000465  ...  -0.000024 -0.000018           1
#
# [20 rows x 4577 columns]

# %% [markdown]
# 階層型クラスタリング(デンドログラム)

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

# %%
def plot_dendrogram(model, **kwargs):
   # Create linkage matrix and then plot the dendrogram

   # create the counts of samples under each node
    #要素の値が全てゼロの配列を作成する
   counts = np.zeros(model.children_.shape[0])
   n_samples = len(model.labels_)
   for i, merge in enumerate(model.children_):
      current_count = 0
      for child_idx in merge:
         if child_idx < n_samples:
            current_count += 1 # leaf node
         else:
            current_count += counts[child_idx - n_samples]
      counts[i] = current_count

   linkage_matrix = np.column_stack([model.children_, model.distances_,
counts]).astype(float)

   # Plot the corresponding dendrogram
   #dendrogram(linkage_matrix, **kwargs,labels = file_names_list,leaf_rotation=90 )#, orientation='left')
   dendrogram(linkage_matrix, **kwargs,labels = file_names_list, orientation='left')

# %% [markdown]
# Can be “euclidean”, “l1”, “l2”, “manhattan”, “cosine”, or “precomputed”. If linkage is “ward”, only “euclidean” is accepted. If “precomputed”, a distance matrix (instead of a similarity matrix) is needed as input for the fit method.

# %% [markdown]
# linkage {‘ward’, ‘complete’, ‘average’, ‘single’}, default=’ward’

# %%
def plot_model_dendlogram (parm_affinity, param_linkage):
  # setting distance_threshold=0 ensures we compute the full tree.
  # affinity: 距離の出す際の計算方法 
  #linkage : 観測セット間で使用する距離 ward マージされるクラスターの分散を最小限に抑える 
  #distance_threshold クラスターはマージされないリンケージ距離のしきい値
  #n_clusters 検索するクラスターの数
  model = AgglomerativeClustering(affinity= parm_affinity,
  linkage= param_linkage, 
  distance_threshold=0,
  n_clusters=None)
  model = model.fit(df)
  fig = plt.figure( figsize=(6,8))
  plt.title(parm_affinity + ', linkage=' + param_linkage )
  # plot the top three levels of the dendrogram
  plot_dendrogram(model, truncate_mode='level')#, p=3)
  plt.xlabel("Number of points in node (or index of point if no parenthesis).")
  #fig.savefig("dendrogram.pdf")
  plt.show()

# %% [markdown]
# ##ward法
# ユークリッド距離のみ

# %% [markdown]
# ユークリッド距離

# %%
# setting distance_threshold=0 ensures we compute the full tree.
# affinity: 距離の出す際の計算方法 
#linkage : 観測セット間で使用する距離 ward マージされるクラスターの分散を最小限に抑える 
#distance_threshold クラスターはマージされないリンケージ距離のしきい値
#n_clusters 検索するクラスターの数
model = AgglomerativeClustering(affinity='euclidean',
linkage='ward', 
distance_threshold=0,
n_clusters=None)

model = model.fit(df)

# %%
fig = plt.figure( figsize=(6,8))
plt.title('Euclidean, linkage=ward')
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode='level')#, p=3)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
#fig.savefig("dendrogram.pdf")
plt.show()

# %%
plot_model_dendlogram ('euclidean', 'ward')

# %% [markdown]
# ##complete

# %% [markdown]
# L1距離

# %%
model = AgglomerativeClustering(affinity='l1',
                                linkage ='complete',
                                distance_threshold=0,
                                n_clusters=None)

model = model.fit(df)

# %%
fig = plt.figure( figsize=(6,8))
plt.title('L1, linkage=complete')
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode='level')#, p=3)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
#fig.savefig("dendrogram.pdf")
plt.show()

# %%
plot_model_dendlogram ('l1', 'complete')

# %% [markdown]
# L2距離

# %%
if False:
  model = AgglomerativeClustering(affinity='l2',
                                  linkage ='complete',
                                  distance_threshold=0,
                                  n_clusters=None)

  model = model.fit(df)

  fig = plt.figure( figsize=(6,8))
  plt.title('L2, linkage=complete')
  # plot the top three levels of the dendrogram
  plot_dendrogram(model, truncate_mode='level')#, p=3)
  plt.xlabel("Number of points in node (or index of point if no parenthesis).")
  #fig.savefig("dendrogram.pdf")
  plt.show()

# %%
plot_model_dendlogram ('l2', 'complete')

# %% [markdown]
# マンハッタン距離

# %%
if False:
  model = AgglomerativeClustering(affinity='manhattan',
                                  linkage ='complete',
                                  distance_threshold=0,
                                  n_clusters=None)

  model = model.fit(df)

  fig = plt.figure( figsize=(6,8))
  plt.title('Manhattan, linkage=complete')
  # plot the top three levels of the dendrogram
  plot_dendrogram(model, truncate_mode='level')#, p=3)
  plt.xlabel("Number of points in node (or index of point if no parenthesis).")
  #fig.savefig("dendrogram.pdf")
  plt.show()

# %%
plot_model_dendlogram ('manhattan', 'complete')

# %% [markdown]
# “cosine”

# %%
if False:
  model = AgglomerativeClustering(affinity='cosine',
                                  linkage ='complete',
                                  distance_threshold=0,
                                  n_clusters=None)

  model = model.fit(df)

  fig = plt.figure( figsize=(6,8))
  plt.title('manhattan, linkage=ward')
  # plot the top three levels of the dendrogram
  plot_dendrogram(model, truncate_mode='level')#, p=3)
  plt.xlabel("Number of points in node (or index of point if no parenthesis).")
  #fig.savefig("dendrogram.pdf")
  plt.show()

# %%
plot_model_dendlogram ('cosine', 'complete')

# %% [markdown]
# ユークリッド

# %%
plot_model_dendlogram ('euclidean', 'complete')

# %% [markdown]
# ##average

# %% [markdown]
# L1

# %%
plot_model_dendlogram ('l1', 'average')

# %% [markdown]
# L2

# %%
plot_model_dendlogram ('l2', 'average')

# %% [markdown]
# manhattan

# %%
plot_model_dendlogram ('manhattan', 'average')

# %% [markdown]
# cosine

# %%
plot_model_dendlogram ('cosine', 'average')

# %% [markdown]
# ユークリッド距離

# %%
plot_model_dendlogram ('euclidean', 'average')

# %%
parm_affinity = 'euclidean'
param_linkage = 'average'
  # setting distance_threshold=0 ensures we compute the full tree.
  # affinity: 距離の出す際の計算方法 
  #linkage : 観測セット間で使用する距離 ward マージされるクラスターの分散を最小限に抑える 
  #distance_threshold クラスターはマージされないリンケージ距離のしきい値
  #n_clusters 検索するクラスターの数
model = AgglomerativeClustering(affinity= parm_affinity,
linkage= param_linkage, 
distance_threshold=0,
n_clusters=None)
model = model.fit(df)
fig = plt.figure( figsize=(6,8))
plt.title(parm_affinity + ', linkage=' + param_linkage )
  # plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode='level')#, p=3)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
  #fig.savefig("dendrogram.pdf")
plt.savefig("dendrogram_sub_euclidean_mean.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# #single

# %% [markdown]
# L1

# %%
plot_model_dendlogram ('l1', 'single')

# %% [markdown]
# L2

# %%
plot_model_dendlogram ('l2', 'single')

# %% [markdown]
# manhattan

# %%
plot_model_dendlogram ('manhattan', 'single')

# %% [markdown]
# cosine

# %%
plot_model_dendlogram ('cosine', 'single')

# %% [markdown]
# ユークリッド距離距離

# %%
plot_model_dendlogram ('euclidean', 'single')
